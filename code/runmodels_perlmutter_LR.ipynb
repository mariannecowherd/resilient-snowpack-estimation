# %% [markdown]
# # Objective
# Assemble predictors for various data combinations and train linear regression models

# %%
import pandas as pd
import xarray as xr
import datetime
import os
import numpy as np
import matplotlib.pyplot as plt
import time

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
### Specify paths to xarrays on your machine, created and saved to a folder called 'Preprocessed_data' by previous notebooks
input_folder_path = '/global/cfs/cdirs/m4099/fate-of-snotel/wrfdata/umital/Preprocessed_data/'

# %%
meta_data = xr.open_dataset(input_folder_path + 'wrfinput_d02')
masks     = xr.open_dataset(input_folder_path + 'basin_masks_filtered.nc')
sweBC     = xr.open_dataarray(input_folder_path + 'snowmaxBC.nc')

snotel_extrap       = xr.open_dataarray(input_folder_path + 'snotel_extrapolated.nc')
cum_precip_all      = xr.open_dataarray(input_folder_path + 'cum_precipBC_SynthErr.nc')
cum_precip_snow_all = xr.open_dataarray(input_folder_path + 'cum_precip_snowBC_SynthErr.nc')
seasonal_t2_all     = xr.open_dataarray(input_folder_path + 'seasonal_t2BC_SynthErr.nc')
mean_fSCA_all       = xr.open_dataarray(input_folder_path + 'mean_fSCABC_SynthErr.nc')
pdd_sum_all         = xr.open_dataarray(input_folder_path + 'pdd_sumBC_SynthErr.nc')
aso_proxy_all       = xr.open_dataarray(input_folder_path + 'swe_apr1_SynthErr.nc')

## Read in static fields

lat_wrf    = meta_data.variables["XLAT"][0,:,:]
lon_wrf    = meta_data.variables["XLONG"][0,:,:]
z_wrf      = meta_data.variables["HGT"][0,:,:]
vgtyp_wrf  = meta_data.variables["IVGTYP"][0,:,:] ## Table 2: IGBP-Modified MODIS 20-category Land Use Categories
vegfra_wrf = meta_data.variables["VEGFRA"][0,:,:] ## Average canopy cover

lat_wrf    = xr.DataArray(lat_wrf, dims=["lat2d", "lon2d"])
lon_wrf    = xr.DataArray(lon_wrf, dims=["lat2d", "lon2d"])
z_wrf      = xr.DataArray(z_wrf, dims=["lat2d", "lon2d"])
vgtyp_wrf  = xr.DataArray(vgtyp_wrf, dims=["lat2d", "lon2d"]) 
vegfra_wrf = xr.DataArray(vegfra_wrf, dims=["lat2d", "lon2d"])

## Compute slope and aspect
myslopx, myslopy = np.gradient(z_wrf, 9000)
slope_wrf = np.degrees(np.arctan(np.sqrt(myslopx**2 + myslopy**2)))
aspect_wrf = np.degrees(np.arctan2(-myslopy,myslopx))
## Convert aspect to compass direction (clockwise from north)
aspect_q2 = (aspect_wrf > 90) & (aspect_wrf <= 180) ## [90, 180]
aspect_wrf = 90.0 - aspect_wrf
aspect_wrf[aspect_q2] = 360.0 + aspect_wrf[aspect_q2]


gcms = ['cesm2','mpi-esm1-2-lr','cnrm-esm2-1',
        'ec-earth3-veg','fgoals-g3','ukesm1-0-ll',
        'canesm5','access-cm2','ec-earth3',]


variants = ['r11i1p1f1','r7i1p1f1','r1i1p1f2',
            'r1i1p1f1','r1i1p1f1','r2i1p1f2',
            'r1i1p2f1','r5i1p1f1','r1i1p1f1',]

gcm_variants = [f'{item1}_{item2}_ssp370' for item1, item2 in zip(gcms, variants)]

# %%
def get_train_test_df (basin_id):
    basinmask = masks.basin_masks[basin_id]
    mask = basinmask.data.astype(bool)
    
    ## Location attributes
    lon_basin = lon_wrf.values[mask]
    lat_basin = lat_wrf.values[mask]

    ## Topography attributes
    z_basin = z_wrf.values[mask]
    slope_basin = slope_wrf[mask]
    aspect_basin = aspect_wrf[mask]

    ## Land-use attributes
    vgtyp_basin = vgtyp_wrf.values[mask]
    vegfra_basin = vegfra_wrf.values[mask]

    #### Create dataframes for training/testing

    Train_df = pd.DataFrame(data = {
                         'knn_snotel' : '',
                         'Longitude'  : np.repeat(lon_basin, train_length),
                         'Latitude'   : np.repeat(lat_basin, train_length),
                         'Elevation'  : np.repeat(z_basin, train_length),
                         'Slope'      : np.repeat(slope_basin, train_length),
                         'Aspect'     : np.repeat(aspect_basin, train_length),
                         'Veg-Type'   : np.repeat(vgtyp_basin, train_length),
                         'Veg-Frac'   : np.repeat(vegfra_basin, train_length),
                         'Cum-fSCA'   : '',
                         'Cum-precip' : '',
                         'Cum-snow'   : '',
                         'Mean-temp'  : '',
                         'PDD-sum'    : '',
                         'ASO-proxy'  : ''})


    Test_df = pd.DataFrame(data = {
                         'knn_snotel' : '',
                         'Longitude'  : lon_basin,
                         'Latitude'   : lat_basin,
                         'Elevation'  : z_basin,
                         'Slope'      : slope_basin,
                         'Aspect'     : aspect_basin,
                         'Veg-Type'   : vgtyp_basin,
                         'Veg-Frac'   : vegfra_basin,
                         'Cum-fSCA'   : '',
                         'Cum-precip' : '',
                         'Cum-snow'   : '',
                         'Mean-temp'  : '',
                         'PDD-sum'    : '',
                         'ASO-proxy'  : ''})
    
    return Train_df, Test_df

# %%
def get_dataarray_basin (basin_id, dataarray):
    basinmask = masks.basin_masks[basin_id]
    mask = basinmask.data.astype(bool)
    return dataarray.values[:,:,mask]

def get_dataarray_gcm_year (gcm_id, years, dataarray):
    return dataarray[gcm_id, years,:].flatten()

def get_KGE(labels, predictions):
    r = np.corrcoef(labels, predictions)[0][1]
    alpha = np.std(predictions)/np.std(labels)
    beta = np.mean(predictions)/np.mean(labels)
    ED = np.sqrt((r-1)**2 + (alpha-1)**2 + (beta-1)**2)
    return 1 - ED

# %%
train_length = 20
test_years = np.arange(2001, 2101, 5)
# test_years = np.arange(2001, 2101)
train_years = [range(item-train_length, item) for item in test_years]

Data_1 = ['knn_snotel', 'Longitude', 'Latitude']
Data_2 = Data_1 + ['Elevation', 'Slope', 'Aspect', 'Veg-Type', 'Veg-Frac']
Data_3 = Data_2 + ['Cum-fSCA']
Data_4 = Data_3 + ['Cum-precip', 'Cum-snow', 'Mean-temp', 'PDD-sum']
Data_5 = Data_4 + ['ASO-proxy']


## Specify folder path
dest_folder = 'Fig4_LR_SynthErr_preds/'

if not os.path.isdir(dest_folder):
    os.mkdir(dest_folder)

# %%
start = time.time()
for basin_id in range(masks.basin.size):

### Will loop over basin_id

    basinname = masks.basin.values[basin_id]
    Train_df, Test_df = get_train_test_df (basin_id)

    ### Take subset of met and swe data here

    knn_snotel_basin      = get_dataarray_basin (basin_id, snotel_extrap)
    cum_precip_basin      = get_dataarray_basin (basin_id, cum_precip_all)
    cum_precip_snow_basin = get_dataarray_basin (basin_id, cum_precip_snow_all)
    seasonal_t2_basin     = get_dataarray_basin (basin_id, seasonal_t2_all)
    pdd_sum_basin         = get_dataarray_basin (basin_id, pdd_sum_all)
    mean_fSCA_basin       = get_dataarray_basin (basin_id, mean_fSCA_all)
    aso_proxy_basin       = get_dataarray_basin (basin_id, aso_proxy_all)
    swe_basin             = get_dataarray_basin (basin_id, sweBC)

    for gcm_id in range(9):
        gcm = gcm_variants[gcm_id]
        print (f"Modeling {basin_id}_{basinname}_{gcm}")
        for test_id in range(test_years.size):
            
            yrs = np.array(train_years[test_id])-1981
            Train_df['knn_snotel'] = get_dataarray_gcm_year (gcm_id, yrs, knn_snotel_basin)
            Train_df['Cum-precip'] = get_dataarray_gcm_year (gcm_id, yrs, cum_precip_basin)
            Train_df['Cum-snow']   = get_dataarray_gcm_year (gcm_id, yrs, cum_precip_snow_basin)
            Train_df['Mean-temp']  = get_dataarray_gcm_year (gcm_id, yrs, seasonal_t2_basin)
            Train_df['PDD-sum']    = get_dataarray_gcm_year (gcm_id, yrs, pdd_sum_basin)
            Train_df['Cum-fSCA']   = get_dataarray_gcm_year (gcm_id, yrs, mean_fSCA_basin)
            Train_df['ASO-proxy']   = get_dataarray_gcm_year (gcm_id, yrs, aso_proxy_basin)

            Test_df['knn_snotel'] = get_dataarray_gcm_year (gcm_id, test_years[test_id]-1981, knn_snotel_basin)
            Test_df['Cum-precip'] = get_dataarray_gcm_year (gcm_id, test_years[test_id]-1981, cum_precip_basin)
            Test_df['Cum-snow']   = get_dataarray_gcm_year (gcm_id, test_years[test_id]-1981, cum_precip_snow_basin)
            Test_df['Mean-temp']  = get_dataarray_gcm_year (gcm_id, test_years[test_id]-1981, seasonal_t2_basin)
            Test_df['PDD-sum']    = get_dataarray_gcm_year (gcm_id, test_years[test_id]-1981, pdd_sum_basin)
            Test_df['Cum-fSCA']   = get_dataarray_gcm_year (gcm_id, test_years[test_id]-1981, mean_fSCA_basin)
            Test_df['ASO-proxy']  = get_dataarray_gcm_year (gcm_id, test_years[test_id]-1981, aso_proxy_basin)

            Train_SWE = get_dataarray_gcm_year (gcm_id, yrs, swe_basin)
            Test_SWE = get_dataarray_gcm_year (gcm_id, test_years[test_id]-1981, swe_basin)
            for data_id, data_var in enumerate([Data_1, Data_2, Data_3, Data_4, Data_5]):
                LR = LinearRegression()
                LR.fit(Train_df[data_var], Train_SWE)

                preds = LR.predict(Test_df[data_var])
                preds[preds < 0.0] = 0.0
                                
                ## Save predictions.
                np.save(dest_folder + f'{basin_id}_{basinname}_{gcm}_{test_years[test_id]}_{data_id}_linreg.npy', preds)

print (f"Time: {time.time()-start} seconds")
# Out:
# Modeling 0_Gunnison_cesm2_r11i1p1f1_ssp370
# Modeling 0_Gunnison_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 0_Gunnison_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 0_Gunnison_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 0_Gunnison_fgoals-g3_r1i1p1f1_ssp370
# Modeling 0_Gunnison_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 0_Gunnison_canesm5_r1i1p2f1_ssp370
# Modeling 0_Gunnison_access-cm2_r5i1p1f1_ssp370
# Modeling 0_Gunnison_ec-earth3_r1i1p1f1_ssp370
# Modeling 1_Fort Peck Lake_cesm2_r11i1p1f1_ssp370
# Modeling 1_Fort Peck Lake_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 1_Fort Peck Lake_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 1_Fort Peck Lake_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 1_Fort Peck Lake_fgoals-g3_r1i1p1f1_ssp370
# Modeling 1_Fort Peck Lake_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 1_Fort Peck Lake_canesm5_r1i1p2f1_ssp370
# Modeling 1_Fort Peck Lake_access-cm2_r5i1p1f1_ssp370
# Modeling 1_Fort Peck Lake_ec-earth3_r1i1p1f1_ssp370
# Modeling 2_Tongue_cesm2_r11i1p1f1_ssp370
# Modeling 2_Tongue_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 2_Tongue_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 2_Tongue_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 2_Tongue_fgoals-g3_r1i1p1f1_ssp370
# Modeling 2_Tongue_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 2_Tongue_canesm5_r1i1p2f1_ssp370
# Modeling 2_Tongue_access-cm2_r5i1p1f1_ssp370
# Modeling 2_Tongue_ec-earth3_r1i1p1f1_ssp370
# Modeling 3_Lower Green_cesm2_r11i1p1f1_ssp370
# Modeling 3_Lower Green_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 3_Lower Green_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 3_Lower Green_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 3_Lower Green_fgoals-g3_r1i1p1f1_ssp370
# Modeling 3_Lower Green_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 3_Lower Green_canesm5_r1i1p2f1_ssp370
# Modeling 3_Lower Green_access-cm2_r5i1p1f1_ssp370
# Modeling 3_Lower Green_ec-earth3_r1i1p1f1_ssp370
# Modeling 4_Pend Oreille_cesm2_r11i1p1f1_ssp370
# Modeling 4_Pend Oreille_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 4_Pend Oreille_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 4_Pend Oreille_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 4_Pend Oreille_fgoals-g3_r1i1p1f1_ssp370
# Modeling 4_Pend Oreille_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 4_Pend Oreille_canesm5_r1i1p2f1_ssp370
# Modeling 4_Pend Oreille_access-cm2_r5i1p1f1_ssp370
# Modeling 4_Pend Oreille_ec-earth3_r1i1p1f1_ssp370
# Modeling 5_Middle Snake-Powder_cesm2_r11i1p1f1_ssp370
# Modeling 5_Middle Snake-Powder_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 5_Middle Snake-Powder_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 5_Middle Snake-Powder_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 5_Middle Snake-Powder_fgoals-g3_r1i1p1f1_ssp370
# Modeling 5_Middle Snake-Powder_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 5_Middle Snake-Powder_canesm5_r1i1p2f1_ssp370
# Modeling 5_Middle Snake-Powder_access-cm2_r5i1p1f1_ssp370
# Modeling 5_Middle Snake-Powder_ec-earth3_r1i1p1f1_ssp370
# Modeling 6_Lower Snake_cesm2_r11i1p1f1_ssp370
# Modeling 6_Lower Snake_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 6_Lower Snake_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 6_Lower Snake_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 6_Lower Snake_fgoals-g3_r1i1p1f1_ssp370
# Modeling 6_Lower Snake_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 6_Lower Snake_canesm5_r1i1p2f1_ssp370
# Modeling 6_Lower Snake_access-cm2_r5i1p1f1_ssp370
# Modeling 6_Lower Snake_ec-earth3_r1i1p1f1_ssp370
# Modeling 7_Upper Arkansas_cesm2_r11i1p1f1_ssp370
# Modeling 7_Upper Arkansas_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 7_Upper Arkansas_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 7_Upper Arkansas_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 7_Upper Arkansas_fgoals-g3_r1i1p1f1_ssp370
# Modeling 7_Upper Arkansas_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 7_Upper Arkansas_canesm5_r1i1p2f1_ssp370
# Modeling 7_Upper Arkansas_access-cm2_r5i1p1f1_ssp370
# Modeling 7_Upper Arkansas_ec-earth3_r1i1p1f1_ssp370
# Modeling 8_Colorado Headwaters_cesm2_r11i1p1f1_ssp370
# Modeling 8_Colorado Headwaters_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 8_Colorado Headwaters_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 8_Colorado Headwaters_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 8_Colorado Headwaters_fgoals-g3_r1i1p1f1_ssp370
# Modeling 8_Colorado Headwaters_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 8_Colorado Headwaters_canesm5_r1i1p2f1_ssp370
# Modeling 8_Colorado Headwaters_access-cm2_r5i1p1f1_ssp370
# Modeling 8_Colorado Headwaters_ec-earth3_r1i1p1f1_ssp370
# Modeling 9_Upper Canadian_cesm2_r11i1p1f1_ssp370
# Modeling 9_Upper Canadian_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 9_Upper Canadian_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 9_Upper Canadian_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 9_Upper Canadian_fgoals-g3_r1i1p1f1_ssp370
# Modeling 9_Upper Canadian_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 9_Upper Canadian_canesm5_r1i1p2f1_ssp370
# Modeling 9_Upper Canadian_access-cm2_r5i1p1f1_ssp370
# Modeling 9_Upper Canadian_ec-earth3_r1i1p1f1_ssp370
# Modeling 10_Spokane_cesm2_r11i1p1f1_ssp370
# Modeling 10_Spokane_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 10_Spokane_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 10_Spokane_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 10_Spokane_fgoals-g3_r1i1p1f1_ssp370
# Modeling 10_Spokane_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 10_Spokane_canesm5_r1i1p2f1_ssp370
# Modeling 10_Spokane_access-cm2_r5i1p1f1_ssp370
# Modeling 10_Spokane_ec-earth3_r1i1p1f1_ssp370
# Modeling 11_Upper San Juan_cesm2_r11i1p1f1_ssp370
# Modeling 11_Upper San Juan_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 11_Upper San Juan_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 11_Upper San Juan_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 11_Upper San Juan_fgoals-g3_r1i1p1f1_ssp370
# Modeling 11_Upper San Juan_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 11_Upper San Juan_canesm5_r1i1p2f1_ssp370
# Modeling 11_Upper San Juan_access-cm2_r5i1p1f1_ssp370
# Modeling 11_Upper San Juan_ec-earth3_r1i1p1f1_ssp370
# Modeling 12_Rio Grande Headwaters_cesm2_r11i1p1f1_ssp370
# Modeling 12_Rio Grande Headwaters_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 12_Rio Grande Headwaters_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 12_Rio Grande Headwaters_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 12_Rio Grande Headwaters_fgoals-g3_r1i1p1f1_ssp370
# Modeling 12_Rio Grande Headwaters_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 12_Rio Grande Headwaters_canesm5_r1i1p2f1_ssp370
# Modeling 12_Rio Grande Headwaters_access-cm2_r5i1p1f1_ssp370
# Modeling 12_Rio Grande Headwaters_ec-earth3_r1i1p1f1_ssp370
# Modeling 13_Lower Sacramento_cesm2_r11i1p1f1_ssp370
# Modeling 13_Lower Sacramento_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 13_Lower Sacramento_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 13_Lower Sacramento_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 13_Lower Sacramento_fgoals-g3_r1i1p1f1_ssp370
# Modeling 13_Lower Sacramento_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 13_Lower Sacramento_canesm5_r1i1p2f1_ssp370
# Modeling 13_Lower Sacramento_access-cm2_r5i1p1f1_ssp370
# Modeling 13_Lower Sacramento_ec-earth3_r1i1p1f1_ssp370
# Modeling 14_Upper Sacramento_cesm2_r11i1p1f1_ssp370
# Modeling 14_Upper Sacramento_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 14_Upper Sacramento_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 14_Upper Sacramento_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 14_Upper Sacramento_fgoals-g3_r1i1p1f1_ssp370
# Modeling 14_Upper Sacramento_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 14_Upper Sacramento_canesm5_r1i1p2f1_ssp370
# Modeling 14_Upper Sacramento_access-cm2_r5i1p1f1_ssp370
# Modeling 14_Upper Sacramento_ec-earth3_r1i1p1f1_ssp370
# Modeling 15_North Lahontan_cesm2_r11i1p1f1_ssp370
# Modeling 15_North Lahontan_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 15_North Lahontan_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 15_North Lahontan_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 15_North Lahontan_fgoals-g3_r1i1p1f1_ssp370
# Modeling 15_North Lahontan_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 15_North Lahontan_canesm5_r1i1p2f1_ssp370
# Modeling 15_North Lahontan_access-cm2_r5i1p1f1_ssp370
# Modeling 15_North Lahontan_ec-earth3_r1i1p1f1_ssp370
# Modeling 16_Truckee_cesm2_r11i1p1f1_ssp370
# Modeling 16_Truckee_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 16_Truckee_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 16_Truckee_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 16_Truckee_fgoals-g3_r1i1p1f1_ssp370
# Modeling 16_Truckee_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 16_Truckee_canesm5_r1i1p2f1_ssp370
# Modeling 16_Truckee_access-cm2_r5i1p1f1_ssp370
# Modeling 16_Truckee_ec-earth3_r1i1p1f1_ssp370
# Modeling 17_Humboldt_cesm2_r11i1p1f1_ssp370
# Modeling 17_Humboldt_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 17_Humboldt_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 17_Humboldt_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 17_Humboldt_fgoals-g3_r1i1p1f1_ssp370
# Modeling 17_Humboldt_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 17_Humboldt_canesm5_r1i1p2f1_ssp370
# Modeling 17_Humboldt_access-cm2_r5i1p1f1_ssp370
# Modeling 17_Humboldt_ec-earth3_r1i1p1f1_ssp370
# Modeling 18_Walker_cesm2_r11i1p1f1_ssp370
# Modeling 18_Walker_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 18_Walker_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 18_Walker_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 18_Walker_fgoals-g3_r1i1p1f1_ssp370
# Modeling 18_Walker_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 18_Walker_canesm5_r1i1p2f1_ssp370
# Modeling 18_Walker_access-cm2_r5i1p1f1_ssp370
# Modeling 18_Walker_ec-earth3_r1i1p1f1_ssp370
# Modeling 19_Marias_cesm2_r11i1p1f1_ssp370
# Modeling 19_Marias_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 19_Marias_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 19_Marias_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 19_Marias_fgoals-g3_r1i1p1f1_ssp370
# Modeling 19_Marias_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 19_Marias_canesm5_r1i1p2f1_ssp370
# Modeling 19_Marias_access-cm2_r5i1p1f1_ssp370
# Modeling 19_Marias_ec-earth3_r1i1p1f1_ssp370
# Modeling 20_North Platte_cesm2_r11i1p1f1_ssp370
# Modeling 20_North Platte_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 20_North Platte_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 20_North Platte_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 20_North Platte_fgoals-g3_r1i1p1f1_ssp370
# Modeling 20_North Platte_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 20_North Platte_canesm5_r1i1p2f1_ssp370
# Modeling 20_North Platte_access-cm2_r5i1p1f1_ssp370
# Modeling 20_North Platte_ec-earth3_r1i1p1f1_ssp370
# Modeling 21_Upper Columbia_cesm2_r11i1p1f1_ssp370
# Modeling 21_Upper Columbia_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 21_Upper Columbia_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 21_Upper Columbia_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 21_Upper Columbia_fgoals-g3_r1i1p1f1_ssp370
# Modeling 21_Upper Columbia_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 21_Upper Columbia_canesm5_r1i1p2f1_ssp370
# Modeling 21_Upper Columbia_access-cm2_r5i1p1f1_ssp370
# Modeling 21_Upper Columbia_ec-earth3_r1i1p1f1_ssp370
# Modeling 22_Upper Missouri_cesm2_r11i1p1f1_ssp370
# Modeling 22_Upper Missouri_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 22_Upper Missouri_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 22_Upper Missouri_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 22_Upper Missouri_fgoals-g3_r1i1p1f1_ssp370
# Modeling 22_Upper Missouri_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 22_Upper Missouri_canesm5_r1i1p2f1_ssp370
# Modeling 22_Upper Missouri_access-cm2_r5i1p1f1_ssp370
# Modeling 22_Upper Missouri_ec-earth3_r1i1p1f1_ssp370
# Modeling 23_Deschutes_cesm2_r11i1p1f1_ssp370
# Modeling 23_Deschutes_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 23_Deschutes_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 23_Deschutes_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 23_Deschutes_fgoals-g3_r1i1p1f1_ssp370
# Modeling 23_Deschutes_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 23_Deschutes_canesm5_r1i1p2f1_ssp370
# Modeling 23_Deschutes_access-cm2_r5i1p1f1_ssp370
# Modeling 23_Deschutes_ec-earth3_r1i1p1f1_ssp370
# Modeling 24_Yakima_cesm2_r11i1p1f1_ssp370
# Modeling 24_Yakima_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 24_Yakima_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 24_Yakima_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 24_Yakima_fgoals-g3_r1i1p1f1_ssp370
# Modeling 24_Yakima_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 24_Yakima_canesm5_r1i1p2f1_ssp370
# Modeling 24_Yakima_access-cm2_r5i1p1f1_ssp370
# Modeling 24_Yakima_ec-earth3_r1i1p1f1_ssp370
# Modeling 25_Puget Sound_cesm2_r11i1p1f1_ssp370
# Modeling 25_Puget Sound_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 25_Puget Sound_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 25_Puget Sound_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 25_Puget Sound_fgoals-g3_r1i1p1f1_ssp370
# Modeling 25_Puget Sound_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 25_Puget Sound_canesm5_r1i1p2f1_ssp370
# Modeling 25_Puget Sound_access-cm2_r5i1p1f1_ssp370
# Modeling 25_Puget Sound_ec-earth3_r1i1p1f1_ssp370
# Modeling 26_San Joaquin_cesm2_r11i1p1f1_ssp370
# Modeling 26_San Joaquin_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 26_San Joaquin_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 26_San Joaquin_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 26_San Joaquin_fgoals-g3_r1i1p1f1_ssp370
# Modeling 26_San Joaquin_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 26_San Joaquin_canesm5_r1i1p2f1_ssp370
# Modeling 26_San Joaquin_access-cm2_r5i1p1f1_ssp370
# Modeling 26_San Joaquin_ec-earth3_r1i1p1f1_ssp370
# Modeling 27_Musselshell_cesm2_r11i1p1f1_ssp370
# Modeling 27_Musselshell_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 27_Musselshell_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 27_Musselshell_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 27_Musselshell_fgoals-g3_r1i1p1f1_ssp370
# Modeling 27_Musselshell_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 27_Musselshell_canesm5_r1i1p2f1_ssp370
# Modeling 27_Musselshell_access-cm2_r5i1p1f1_ssp370
# Modeling 27_Musselshell_ec-earth3_r1i1p1f1_ssp370
# Modeling 28_Weber_cesm2_r11i1p1f1_ssp370
# Modeling 28_Weber_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 28_Weber_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 28_Weber_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 28_Weber_fgoals-g3_r1i1p1f1_ssp370
# Modeling 28_Weber_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 28_Weber_canesm5_r1i1p2f1_ssp370
# Modeling 28_Weber_access-cm2_r5i1p1f1_ssp370
# Modeling 28_Weber_ec-earth3_r1i1p1f1_ssp370
# Modeling 29_Jordan_cesm2_r11i1p1f1_ssp370
# Modeling 29_Jordan_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 29_Jordan_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 29_Jordan_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 29_Jordan_fgoals-g3_r1i1p1f1_ssp370
# Modeling 29_Jordan_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 29_Jordan_canesm5_r1i1p2f1_ssp370
# Modeling 29_Jordan_access-cm2_r5i1p1f1_ssp370
# Modeling 29_Jordan_ec-earth3_r1i1p1f1_ssp370
# Modeling 30_Powder_cesm2_r11i1p1f1_ssp370
# Modeling 30_Powder_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 30_Powder_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 30_Powder_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 30_Powder_fgoals-g3_r1i1p1f1_ssp370
# Modeling 30_Powder_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 30_Powder_canesm5_r1i1p2f1_ssp370
# Modeling 30_Powder_access-cm2_r5i1p1f1_ssp370
# Modeling 30_Powder_ec-earth3_r1i1p1f1_ssp370
# Modeling 31_Salmon_cesm2_r11i1p1f1_ssp370
# Modeling 31_Salmon_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 31_Salmon_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 31_Salmon_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 31_Salmon_fgoals-g3_r1i1p1f1_ssp370
# Modeling 31_Salmon_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 31_Salmon_canesm5_r1i1p2f1_ssp370
# Modeling 31_Salmon_access-cm2_r5i1p1f1_ssp370
# Modeling 31_Salmon_ec-earth3_r1i1p1f1_ssp370
# Modeling 32_Clearwater_cesm2_r11i1p1f1_ssp370
# Modeling 32_Clearwater_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 32_Clearwater_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 32_Clearwater_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 32_Clearwater_fgoals-g3_r1i1p1f1_ssp370
# Modeling 32_Clearwater_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 32_Clearwater_canesm5_r1i1p2f1_ssp370
# Modeling 32_Clearwater_access-cm2_r5i1p1f1_ssp370
# Modeling 32_Clearwater_ec-earth3_r1i1p1f1_ssp370
# Modeling 33_Middle Snake-Boise_cesm2_r11i1p1f1_ssp370
# Modeling 33_Middle Snake-Boise_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 33_Middle Snake-Boise_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 33_Middle Snake-Boise_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 33_Middle Snake-Boise_fgoals-g3_r1i1p1f1_ssp370
# Modeling 33_Middle Snake-Boise_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 33_Middle Snake-Boise_canesm5_r1i1p2f1_ssp370
# Modeling 33_Middle Snake-Boise_access-cm2_r5i1p1f1_ssp370
# Modeling 33_Middle Snake-Boise_ec-earth3_r1i1p1f1_ssp370
# Modeling 34_John Day_cesm2_r11i1p1f1_ssp370
# Modeling 34_John Day_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 34_John Day_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 34_John Day_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 34_John Day_fgoals-g3_r1i1p1f1_ssp370
# Modeling 34_John Day_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 34_John Day_canesm5_r1i1p2f1_ssp370
# Modeling 34_John Day_access-cm2_r5i1p1f1_ssp370
# Modeling 34_John Day_ec-earth3_r1i1p1f1_ssp370
# Modeling 35_Black Rock Desert_cesm2_r11i1p1f1_ssp370
# Modeling 35_Black Rock Desert_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 35_Black Rock Desert_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 35_Black Rock Desert_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 35_Black Rock Desert_fgoals-g3_r1i1p1f1_ssp370
# Modeling 35_Black Rock Desert_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 35_Black Rock Desert_canesm5_r1i1p2f1_ssp370
# Modeling 35_Black Rock Desert_access-cm2_r5i1p1f1_ssp370
# Modeling 35_Black Rock Desert_ec-earth3_r1i1p1f1_ssp370
# Modeling 36_Upper South Saskatchewan River_cesm2_r11i1p1f1_ssp370
# Modeling 36_Upper South Saskatchewan River_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 36_Upper South Saskatchewan River_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 36_Upper South Saskatchewan River_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 36_Upper South Saskatchewan River_fgoals-g3_r1i1p1f1_ssp370
# Modeling 36_Upper South Saskatchewan River_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 36_Upper South Saskatchewan River_canesm5_r1i1p2f1_ssp370
# Modeling 36_Upper South Saskatchewan River_access-cm2_r5i1p1f1_ssp370
# Modeling 36_Upper South Saskatchewan River_ec-earth3_r1i1p1f1_ssp370
# Modeling 37_South Platte_cesm2_r11i1p1f1_ssp370
# Modeling 37_South Platte_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 37_South Platte_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 37_South Platte_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 37_South Platte_fgoals-g3_r1i1p1f1_ssp370
# Modeling 37_South Platte_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 37_South Platte_canesm5_r1i1p2f1_ssp370
# Modeling 37_South Platte_access-cm2_r5i1p1f1_ssp370
# Modeling 37_South Platte_ec-earth3_r1i1p1f1_ssp370
# Modeling 38_Missouri Headwaters_cesm2_r11i1p1f1_ssp370
# Modeling 38_Missouri Headwaters_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 38_Missouri Headwaters_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 38_Missouri Headwaters_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 38_Missouri Headwaters_fgoals-g3_r1i1p1f1_ssp370
# Modeling 38_Missouri Headwaters_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 38_Missouri Headwaters_canesm5_r1i1p2f1_ssp370
# Modeling 38_Missouri Headwaters_access-cm2_r5i1p1f1_ssp370
# Modeling 38_Missouri Headwaters_ec-earth3_r1i1p1f1_ssp370
# Modeling 39_Upper Yellowstone_cesm2_r11i1p1f1_ssp370
# Modeling 39_Upper Yellowstone_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 39_Upper Yellowstone_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 39_Upper Yellowstone_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 39_Upper Yellowstone_fgoals-g3_r1i1p1f1_ssp370
# Modeling 39_Upper Yellowstone_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 39_Upper Yellowstone_canesm5_r1i1p2f1_ssp370
# Modeling 39_Upper Yellowstone_access-cm2_r5i1p1f1_ssp370
# Modeling 39_Upper Yellowstone_ec-earth3_r1i1p1f1_ssp370
# Modeling 40_Big Horn_cesm2_r11i1p1f1_ssp370
# Modeling 40_Big Horn_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 40_Big Horn_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 40_Big Horn_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 40_Big Horn_fgoals-g3_r1i1p1f1_ssp370
# Modeling 40_Big Horn_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 40_Big Horn_canesm5_r1i1p2f1_ssp370
# Modeling 40_Big Horn_access-cm2_r5i1p1f1_ssp370
# Modeling 40_Big Horn_ec-earth3_r1i1p1f1_ssp370
# Modeling 41_Upper Rio Grande_cesm2_r11i1p1f1_ssp370
# Modeling 41_Upper Rio Grande_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 41_Upper Rio Grande_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 41_Upper Rio Grande_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 41_Upper Rio Grande_fgoals-g3_r1i1p1f1_ssp370
# Modeling 41_Upper Rio Grande_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 41_Upper Rio Grande_canesm5_r1i1p2f1_ssp370
# Modeling 41_Upper Rio Grande_access-cm2_r5i1p1f1_ssp370
# Modeling 41_Upper Rio Grande_ec-earth3_r1i1p1f1_ssp370
# Modeling 42_Rio Grande-Elephant Butte_cesm2_r11i1p1f1_ssp370
# Modeling 42_Rio Grande-Elephant Butte_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 42_Rio Grande-Elephant Butte_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 42_Rio Grande-Elephant Butte_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 42_Rio Grande-Elephant Butte_fgoals-g3_r1i1p1f1_ssp370
# Modeling 42_Rio Grande-Elephant Butte_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 42_Rio Grande-Elephant Butte_canesm5_r1i1p2f1_ssp370
# Modeling 42_Rio Grande-Elephant Butte_access-cm2_r5i1p1f1_ssp370
# Modeling 42_Rio Grande-Elephant Butte_ec-earth3_r1i1p1f1_ssp370
# Modeling 43_Upper Pecos_cesm2_r11i1p1f1_ssp370
# Modeling 43_Upper Pecos_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 43_Upper Pecos_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 43_Upper Pecos_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 43_Upper Pecos_fgoals-g3_r1i1p1f1_ssp370
# Modeling 43_Upper Pecos_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 43_Upper Pecos_canesm5_r1i1p2f1_ssp370
# Modeling 43_Upper Pecos_access-cm2_r5i1p1f1_ssp370
# Modeling 43_Upper Pecos_ec-earth3_r1i1p1f1_ssp370
# Modeling 44_Lower San Juan_cesm2_r11i1p1f1_ssp370
# Modeling 44_Lower San Juan_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 44_Lower San Juan_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 44_Lower San Juan_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 44_Lower San Juan_fgoals-g3_r1i1p1f1_ssp370
# Modeling 44_Lower San Juan_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 44_Lower San Juan_canesm5_r1i1p2f1_ssp370
# Modeling 44_Lower San Juan_access-cm2_r5i1p1f1_ssp370
# Modeling 44_Lower San Juan_ec-earth3_r1i1p1f1_ssp370
# Modeling 45_Upper Colorado-Dirty Devil_cesm2_r11i1p1f1_ssp370
# Modeling 45_Upper Colorado-Dirty Devil_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 45_Upper Colorado-Dirty Devil_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 45_Upper Colorado-Dirty Devil_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 45_Upper Colorado-Dirty Devil_fgoals-g3_r1i1p1f1_ssp370
# Modeling 45_Upper Colorado-Dirty Devil_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 45_Upper Colorado-Dirty Devil_canesm5_r1i1p2f1_ssp370
# Modeling 45_Upper Colorado-Dirty Devil_access-cm2_r5i1p1f1_ssp370
# Modeling 45_Upper Colorado-Dirty Devil_ec-earth3_r1i1p1f1_ssp370
# Modeling 46_Upper Colorado-Dolores_cesm2_r11i1p1f1_ssp370
# Modeling 46_Upper Colorado-Dolores_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 46_Upper Colorado-Dolores_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 46_Upper Colorado-Dolores_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 46_Upper Colorado-Dolores_fgoals-g3_r1i1p1f1_ssp370
# Modeling 46_Upper Colorado-Dolores_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 46_Upper Colorado-Dolores_canesm5_r1i1p2f1_ssp370
# Modeling 46_Upper Colorado-Dolores_access-cm2_r5i1p1f1_ssp370
# Modeling 46_Upper Colorado-Dolores_ec-earth3_r1i1p1f1_ssp370
# Modeling 47_Upper Green_cesm2_r11i1p1f1_ssp370
# Modeling 47_Upper Green_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 47_Upper Green_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 47_Upper Green_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 47_Upper Green_fgoals-g3_r1i1p1f1_ssp370
# Modeling 47_Upper Green_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 47_Upper Green_canesm5_r1i1p2f1_ssp370
# Modeling 47_Upper Green_access-cm2_r5i1p1f1_ssp370
# Modeling 47_Upper Green_ec-earth3_r1i1p1f1_ssp370
# Modeling 48_White-Yampa_cesm2_r11i1p1f1_ssp370
# Modeling 48_White-Yampa_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 48_White-Yampa_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 48_White-Yampa_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 48_White-Yampa_fgoals-g3_r1i1p1f1_ssp370
# Modeling 48_White-Yampa_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 48_White-Yampa_canesm5_r1i1p2f1_ssp370
# Modeling 48_White-Yampa_access-cm2_r5i1p1f1_ssp370
# Modeling 48_White-Yampa_ec-earth3_r1i1p1f1_ssp370
# Modeling 49_Verde_cesm2_r11i1p1f1_ssp370
# Modeling 49_Verde_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 49_Verde_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 49_Verde_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 49_Verde_fgoals-g3_r1i1p1f1_ssp370
# Modeling 49_Verde_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 49_Verde_canesm5_r1i1p2f1_ssp370
# Modeling 49_Verde_access-cm2_r5i1p1f1_ssp370
# Modeling 49_Verde_ec-earth3_r1i1p1f1_ssp370
# Modeling 50_Little Colorado_cesm2_r11i1p1f1_ssp370
# Modeling 50_Little Colorado_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 50_Little Colorado_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 50_Little Colorado_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 50_Little Colorado_fgoals-g3_r1i1p1f1_ssp370
# Modeling 50_Little Colorado_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 50_Little Colorado_canesm5_r1i1p2f1_ssp370
# Modeling 50_Little Colorado_access-cm2_r5i1p1f1_ssp370
# Modeling 50_Little Colorado_ec-earth3_r1i1p1f1_ssp370
# Modeling 51_Lower Colorado-Lake Mead_cesm2_r11i1p1f1_ssp370
# Modeling 51_Lower Colorado-Lake Mead_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 51_Lower Colorado-Lake Mead_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 51_Lower Colorado-Lake Mead_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 51_Lower Colorado-Lake Mead_fgoals-g3_r1i1p1f1_ssp370
# Modeling 51_Lower Colorado-Lake Mead_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 51_Lower Colorado-Lake Mead_canesm5_r1i1p2f1_ssp370
# Modeling 51_Lower Colorado-Lake Mead_access-cm2_r5i1p1f1_ssp370
# Modeling 51_Lower Colorado-Lake Mead_ec-earth3_r1i1p1f1_ssp370
# Modeling 52_Carson_cesm2_r11i1p1f1_ssp370
# Modeling 52_Carson_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 52_Carson_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 52_Carson_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 52_Carson_fgoals-g3_r1i1p1f1_ssp370
# Modeling 52_Carson_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 52_Carson_canesm5_r1i1p2f1_ssp370
# Modeling 52_Carson_access-cm2_r5i1p1f1_ssp370
# Modeling 52_Carson_ec-earth3_r1i1p1f1_ssp370
# Modeling 53_Central Nevada Desert Basins_cesm2_r11i1p1f1_ssp370
# Modeling 53_Central Nevada Desert Basins_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 53_Central Nevada Desert Basins_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 53_Central Nevada Desert Basins_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 53_Central Nevada Desert Basins_fgoals-g3_r1i1p1f1_ssp370
# Modeling 53_Central Nevada Desert Basins_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 53_Central Nevada Desert Basins_canesm5_r1i1p2f1_ssp370
# Modeling 53_Central Nevada Desert Basins_access-cm2_r5i1p1f1_ssp370
# Modeling 53_Central Nevada Desert Basins_ec-earth3_r1i1p1f1_ssp370
# Modeling 54_Lower Bear_cesm2_r11i1p1f1_ssp370
# Modeling 54_Lower Bear_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 54_Lower Bear_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 54_Lower Bear_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 54_Lower Bear_fgoals-g3_r1i1p1f1_ssp370
# Modeling 54_Lower Bear_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 54_Lower Bear_canesm5_r1i1p2f1_ssp370
# Modeling 54_Lower Bear_access-cm2_r5i1p1f1_ssp370
# Modeling 54_Lower Bear_ec-earth3_r1i1p1f1_ssp370
# Modeling 55_Upper Bear_cesm2_r11i1p1f1_ssp370
# Modeling 55_Upper Bear_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 55_Upper Bear_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 55_Upper Bear_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 55_Upper Bear_fgoals-g3_r1i1p1f1_ssp370
# Modeling 55_Upper Bear_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 55_Upper Bear_canesm5_r1i1p2f1_ssp370
# Modeling 55_Upper Bear_access-cm2_r5i1p1f1_ssp370
# Modeling 55_Upper Bear_ec-earth3_r1i1p1f1_ssp370
# Modeling 56_Great Salt Lake_cesm2_r11i1p1f1_ssp370
# Modeling 56_Great Salt Lake_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 56_Great Salt Lake_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 56_Great Salt Lake_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 56_Great Salt Lake_fgoals-g3_r1i1p1f1_ssp370
# Modeling 56_Great Salt Lake_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 56_Great Salt Lake_canesm5_r1i1p2f1_ssp370
# Modeling 56_Great Salt Lake_access-cm2_r5i1p1f1_ssp370
# Modeling 56_Great Salt Lake_ec-earth3_r1i1p1f1_ssp370
# Modeling 57_Escalante Desert-Sevier Lake_cesm2_r11i1p1f1_ssp370
# Modeling 57_Escalante Desert-Sevier Lake_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 57_Escalante Desert-Sevier Lake_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 57_Escalante Desert-Sevier Lake_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 57_Escalante Desert-Sevier Lake_fgoals-g3_r1i1p1f1_ssp370
# Modeling 57_Escalante Desert-Sevier Lake_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 57_Escalante Desert-Sevier Lake_canesm5_r1i1p2f1_ssp370
# Modeling 57_Escalante Desert-Sevier Lake_access-cm2_r5i1p1f1_ssp370
# Modeling 57_Escalante Desert-Sevier Lake_ec-earth3_r1i1p1f1_ssp370
# Modeling 58_Southern Oregon Coastal_cesm2_r11i1p1f1_ssp370
# Modeling 58_Southern Oregon Coastal_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 58_Southern Oregon Coastal_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 58_Southern Oregon Coastal_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 58_Southern Oregon Coastal_fgoals-g3_r1i1p1f1_ssp370
# Modeling 58_Southern Oregon Coastal_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 58_Southern Oregon Coastal_canesm5_r1i1p2f1_ssp370
# Modeling 58_Southern Oregon Coastal_access-cm2_r5i1p1f1_ssp370
# Modeling 58_Southern Oregon Coastal_ec-earth3_r1i1p1f1_ssp370
# Modeling 59_Upper Snake_cesm2_r11i1p1f1_ssp370
# Modeling 59_Upper Snake_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 59_Upper Snake_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 59_Upper Snake_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 59_Upper Snake_fgoals-g3_r1i1p1f1_ssp370
# Modeling 59_Upper Snake_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 59_Upper Snake_canesm5_r1i1p2f1_ssp370
# Modeling 59_Upper Snake_access-cm2_r5i1p1f1_ssp370
# Modeling 59_Upper Snake_ec-earth3_r1i1p1f1_ssp370
# Modeling 60_Snake Headwaters_cesm2_r11i1p1f1_ssp370
# Modeling 60_Snake Headwaters_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 60_Snake Headwaters_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 60_Snake Headwaters_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 60_Snake Headwaters_fgoals-g3_r1i1p1f1_ssp370
# Modeling 60_Snake Headwaters_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 60_Snake Headwaters_canesm5_r1i1p2f1_ssp370
# Modeling 60_Snake Headwaters_access-cm2_r5i1p1f1_ssp370
# Modeling 60_Snake Headwaters_ec-earth3_r1i1p1f1_ssp370
# Modeling 61_Kootenai_cesm2_r11i1p1f1_ssp370
# Modeling 61_Kootenai_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 61_Kootenai_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 61_Kootenai_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 61_Kootenai_fgoals-g3_r1i1p1f1_ssp370
# Modeling 61_Kootenai_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 61_Kootenai_canesm5_r1i1p2f1_ssp370
# Modeling 61_Kootenai_access-cm2_r5i1p1f1_ssp370
# Modeling 61_Kootenai_ec-earth3_r1i1p1f1_ssp370
# Modeling 62_Oregon Closed Basins_cesm2_r11i1p1f1_ssp370
# Modeling 62_Oregon Closed Basins_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 62_Oregon Closed Basins_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 62_Oregon Closed Basins_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 62_Oregon Closed Basins_fgoals-g3_r1i1p1f1_ssp370
# Modeling 62_Oregon Closed Basins_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 62_Oregon Closed Basins_canesm5_r1i1p2f1_ssp370
# Modeling 62_Oregon Closed Basins_access-cm2_r5i1p1f1_ssp370
# Modeling 62_Oregon Closed Basins_ec-earth3_r1i1p1f1_ssp370
# Modeling 63_Middle Columbia_cesm2_r11i1p1f1_ssp370
# Modeling 63_Middle Columbia_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 63_Middle Columbia_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 63_Middle Columbia_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 63_Middle Columbia_fgoals-g3_r1i1p1f1_ssp370
# Modeling 63_Middle Columbia_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 63_Middle Columbia_canesm5_r1i1p2f1_ssp370
# Modeling 63_Middle Columbia_access-cm2_r5i1p1f1_ssp370
# Modeling 63_Middle Columbia_ec-earth3_r1i1p1f1_ssp370
# Modeling 64_Klamath_cesm2_r11i1p1f1_ssp370
# Modeling 64_Klamath_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 64_Klamath_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 64_Klamath_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 64_Klamath_fgoals-g3_r1i1p1f1_ssp370
# Modeling 64_Klamath_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 64_Klamath_canesm5_r1i1p2f1_ssp370
# Modeling 64_Klamath_access-cm2_r5i1p1f1_ssp370
# Modeling 64_Klamath_ec-earth3_r1i1p1f1_ssp370
# Modeling 65_Northern Oregon Coastal_cesm2_r11i1p1f1_ssp370
# Modeling 65_Northern Oregon Coastal_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 65_Northern Oregon Coastal_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 65_Northern Oregon Coastal_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 65_Northern Oregon Coastal_fgoals-g3_r1i1p1f1_ssp370
# Modeling 65_Northern Oregon Coastal_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 65_Northern Oregon Coastal_canesm5_r1i1p2f1_ssp370
# Modeling 65_Northern Oregon Coastal_access-cm2_r5i1p1f1_ssp370
# Modeling 65_Northern Oregon Coastal_ec-earth3_r1i1p1f1_ssp370
# Modeling 66_Lower Columbia_cesm2_r11i1p1f1_ssp370
# Modeling 66_Lower Columbia_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 66_Lower Columbia_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 66_Lower Columbia_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 66_Lower Columbia_fgoals-g3_r1i1p1f1_ssp370
# Modeling 66_Lower Columbia_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 66_Lower Columbia_canesm5_r1i1p2f1_ssp370
# Modeling 66_Lower Columbia_access-cm2_r5i1p1f1_ssp370
# Modeling 66_Lower Columbia_ec-earth3_r1i1p1f1_ssp370
# Modeling 67_Willamette_cesm2_r11i1p1f1_ssp370
# Modeling 67_Willamette_mpi-esm1-2-lr_r7i1p1f1_ssp370
# Modeling 67_Willamette_cnrm-esm2-1_r1i1p1f2_ssp370
# Modeling 67_Willamette_ec-earth3-veg_r1i1p1f1_ssp370
# Modeling 67_Willamette_fgoals-g3_r1i1p1f1_ssp370
# Modeling 67_Willamette_ukesm1-0-ll_r2i1p1f2_ssp370
# Modeling 67_Willamette_canesm5_r1i1p2f1_ssp370
# Modeling 67_Willamette_access-cm2_r5i1p1f1_ssp370
# Modeling 67_Willamette_ec-earth3_r1i1p1f1_ssp370
# Time: 1712.250803232193 seconds
